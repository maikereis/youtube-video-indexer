# %%
import os
import json
import requests
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %%
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
GOOGLE_API_URL = os.getenv("GOOGLE_API_URL")

# %%
from dataclasses import dataclass, asdict
from datetime import datetime


@dataclass
class Video:
    id: str
    title: str
    url: str
    description: str
    published_at: datetime


@dataclass
class Channel:
    id: str
    name: str
    videos: list[Video] = None

    def __post_init__(self):
        self.videos = []

    def add_video(self, video: Video):
        self.videos.append(video)

# %%
channells = [
    {"name": "ByteByteGo", "id": "UCZgt6AzoyjslHTC9dz0UoTw"},
    {"name": "IBM Technology", "id": "UCKWaEZ-_VweaEx1j62do_vQ"},
    {"name": "Sebastian Rashka", "id": "UC_CzsS7UTjcxJ-xXp1ftxtA"},
    {"name": "FreeCodeCamp.org", "id": "UC8butISFwT-Wl7EV0hUK0BQ"},
]

channel_list = [Channel(**channel) for channel in channells]

# %%
channel_list
# Out:
# [Channel(id='UCZgt6AzoyjslHTC9dz0UoTw', name='ByteByteGo', videos=[]),
#  Channel(id='UCKWaEZ-_VweaEx1j62do_vQ', name='IBM Technology', videos=[]),
#  Channel(id='UC_CzsS7UTjcxJ-xXp1ftxtA', name='Sebastian Rashka', videos=[]),
#  Channel(id='UC8butISFwT-Wl7EV0hUK0BQ', name='FreeCodeCamp.org', videos=[])]

# %%
for channel in channel_list:
    skip = False

    params = {
        "key": GOOGLE_API_KEY,
        "channelId": channel.id,
        "part": ["snippet", "id"],
        "order": "date",
        "maxResults": 50,
        "pageToken": None,
    }

    while not skip:
        response = requests.get(GOOGLE_API_URL, params=params)
        data = response.json()

        if "items" in data:
            for item in data["items"]:
                if item["id"]["kind"] == "youtube#video":
                    video_id = item["id"]["videoId"]
                    video_title = item["snippet"]["title"]
                    video_description = item["snippet"]["description"]
                    video_published_at = item["snippet"]["publishTime"]
                    video_url = f"https://www.youtube.com/watch?v={video_id}"

                    try:
                        video_published_at = datetime.strptime(
                            item["snippet"]["publishTime"], "%Y-%m-%dT%H:%M:%SZ"
                        )
                    except ValueError:
                        video_published_at = None

                    video = Video(
                        id=video_id,
                        title=video_title,
                        url=video_url,
                        description=video_description,
                        published_at=video_published_at,
                    )

                    channel.add_video(video)

        if "nextPageToken" not in data:
            skip = True
        else:
            params["pageToken"] = data.get("nextPageToken")

# %%
channel_list
# Out:
# [Channel(id='UCZgt6AzoyjslHTC9dz0UoTw', name='ByteByteGo', videos=[Video(id='wvLdBJEl-wc', title='Why is Kafka FAST? Part 1', url='https://www.youtube.com/watch?v=wvLdBJEl-wc', description='', published_at=datetime.datetime(2025, 5, 8, 14, 45, 59)), Video(id='2g1G8Jr88xU', title='System Design Was HARD - Until You Knew the Trade-Offs, Part 2', url='https://www.youtube.com/watch?v=2g1G8Jr88xU', description='Sign up now to access ChatLLM: https://bit.ly/42RlGDV Get a Free System Design PDF with 158 pages by subscribing to our ...', published_at=datetime.datetime(2025, 4, 30, 15, 30, 3)), Video(id='1nENigGr-a0', title='System Design Was HARD - Until You Knew the Trade-Offs', url='https://www.youtube.com/watch?v=1nENigGr-a0', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 4, 22, 15, 30)), Video(id='f7KgDNZU3-Y', title='gRPC, WebSocket and WebHook!', url='https://www.youtube.com/watch?v=f7KgDNZU3-Y', description='', published_at=datetime.datetime(2025, 4, 18, 5, 17, 15)), Video(id='_d0duu3dED4', title='Why Everyone’s Talking About MCP?', url='https://www.youtube.com/watch?v=_d0duu3dED4', description="Fixed 2:44–3:10 in the video uploaded to X (we're unable to edit videos that are already uploaded to YouTube): ...", published_at=datetime.datetime(2025, 4, 2, 15, 30, 14)), Video(id='PNRbanEKGtw', title='Top 6 Most Popular API Architecture Styles', url='https://www.youtube.com/watch?v=PNRbanEKGtw', description='', published_at=datetime.datetime(2025, 3, 26, 15, 30, 10)), Video(id='eHEHE2fpnWQ', title='What Are AI Agents Really About?', url='https://www.youtube.com/watch?v=eHEHE2fpnWQ', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 3, 19, 15, 30, 14)), Video(id='rQhost93z40', title='What is GraphQL?', url='https://www.youtube.com/watch?v=rQhost93z40', description='GraphQL - Provides a single endpoint for clients to query for precisely the data they need. - Clients specify the exact fields ...', published_at=datetime.datetime(2025, 3, 10, 14, 55, 18)), Video(id='hFURlsMwU7c', title='What Is the Most Popular Open-Source AI Stack?', url='https://www.youtube.com/watch?v=hFURlsMwU7c', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 3, 5, 16, 44, 2)), Video(id='3Lis4w4_bBc', title='8 Most Important Tips for Designing Fault-Tolerant System', url='https://www.youtube.com/watch?v=3Lis4w4_bBc', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 2, 25, 16, 30, 1)), Video(id='3Kqal7QaCCM', title='How the Garbage Collector Works in Java, Python, and Go!', url='https://www.youtube.com/watch?v=3Kqal7QaCCM', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 2, 13, 16, 30, 1)), Video(id='QEzbZKtLi-g', title='System Design: Why Is Docker Important?', url='https://www.youtube.com/watch?v=QEzbZKtLi-g', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 2, 3, 16, 30, 11)), Video(id='LQuuoHTyYz8', title='What is a LOAD BALANCER really about?', url='https://www.youtube.com/watch?v=LQuuoHTyYz8', description='Get a Free System Design PDF with 158 pages by subscribing to our weekly newsletter: https://bit.ly/bbg-social Animation tools: ...', published_at=datetime.datetime(2025, 1, 23, 16, 30, 6)), Video(id='GhX8sNyFo5w', title='API Vs SDK! What&#39;s the difference? ...
#  Channel(id='UCKWaEZ-_VweaEx1j62do_vQ', name='IBM Technology', videos=[Video(id='yhR3ecXldV4', title='IBM Think 2025: 150+ AI Agents Unleashed!', url='https://www.youtube.com/watch?v=yhR3ecXldV4', description='Kaoutar El Maghraoui shares how IBM Think 2025 showcased 150+ pre-built AI agents via watsonx Orchestrate, boosting ...', published_at=datetime.datetime(2025, 5, 9, 19, 2, 21)), Video(id='5M-VD9F1W7A', title='IBM Think 2025, OpenAI Windsurf acquisition, reasoning models and hallucinations', url='https://www.youtube.com/watch?v=5M-VD9F1W7A', description='Learn more about artificial intelligence → https://ibm.biz/BdnvEu Has AI hallucination gotten out of control? In episode 54 of ...', published_at=datetime.datetime(2025, 5, 9, 10, 0, 8)), Video(id='AuV62XbiZcw', title='What Are AI Identities? Understanding Agentic Systems &amp; Governance', url='https://www.youtube.com/watch?v=AuV62XbiZcw', description='Ready to become a certified Architect - Cloud Pak for Data? Register now and use code IBMTechYT20 for 20% off of your exam ...', published_at=datetime.datetime(2025, 5, 8, 11, 0, 28)), Video(id='W_FaxJMhuTQ', title='AI Chatbots: NLP &amp; Emotional Intelligence', url='https://www.youtube.com/watch?v=W_FaxJMhuTQ', description='Learn more about AI Chatbots here → https://ibm.biz/BdnqMq How human should AI chatbots be? Discover how NLP ...', published_at=datetime.datetime(2025, 5, 7, 17, 0, 41)), Video(id='0S7zbkTCYbs', title='How Data Lakehouses Improve Generative AI Accuracy', url='https://www.youtube.com/watch?v=0S7zbkTCYbs', description='Ready to become a certified watsonx Data Lakehouse Engineer? Register now and use code IBMTechYT20 for 20% off of your ...', published_at=datetime.datetime(2025, 5, 7, 11, 0, 5)), Video(id='Le86PMGK2Uk', title='Language Concept Models: The Next Leap in Generative AI', url='https://www.youtube.com/watch?v=Le86PMGK2Uk', description='Ready to become a certified watsonx AI Assistant Engineer? Register now and use code IBMTechYT20 for 20% off of your exam ...', published_at=datetime.datetime(2025, 5, 6, 11, 0, 36)), Video(id='7j1t3UZA1TY', title='MCP vs API: Simplifying AI Agent Integration with External Data', url='https://www.youtube.com/watch?v=7j1t3UZA1TY', description='Ready to become a certified Solution Implementer? Register now and use code IBMTechYT20 for 20% off of your exam ...', published_at=datetime.datetime(2025, 5, 5, 11, 0, 12)), Video(id='7D4fiRvSWMI', title='Qwen3’s hybrid thinking explained', url='https://www.youtube.com/watch?v=7D4fiRvSWMI', description='Qwen3 uses "thinking" and "non-thinking" modes to solve problems. Listen to AI expert, Chris Hay, explain how hybrid AI models ...', published_at=datetime.datetime(2025, 5, 2, 21, 15, 24)), Video(id='yeutlpU13YM', title='LlamaCon, Qwen3, DeepSeek-R2 rumors and JP Morgan’s open letter on AI', url='https://www.youtube.com/watch?v=yeutlpU13YM', description="Visit Mixture of Experts podcast page to learn more AI content → https://ibm.biz/BdnPYG We are celebrating MoE podcast's one ...", published_at=datetime.datetime(2025, 5, 2, 10, 1, 36)), Video(id='Yq29bZ8Hlrc', title='Optimize RAG with AI Agents &amp; Vector Databases', url='https://www.youtube.com/watch?v=Yq29bZ8Hlrc', description='Ready to become a certified Administrator on IBM Cloud Pak for Integration? Register now and use code IBMTechYT20 for 20% ...', published_at=datetime.datetime(2025, 4, 30, 11, 1)), Video(id='swp1QJZQzEw', title='What is AI Data Management? Discover, Clean, &amp; Secure Data with AI', url='https://www.youtube.com/watch?v=swp1QJZQzEw', description='Ready to become a certified Deployment Professional? Register now and use code IBMTechYT20 for 20% off of your exam ...', published_at=datetime.datetime(2025, 4, 29, 11, 1, 33)), Video(id='aofmtE6Rp-w', title='2025 Cyber Threats: Ransomware &amp; Beyond', url='https://www.youtube.com/watch?v=aofmtE6Rp-w', description='Want to uncover the latest insights on ransomware, dark web threats, and AI risks? Rea ...
#  Channel(id='UC_CzsS7UTjcxJ-xXp1ftxtA', name='Sebastian Rashka', videos=[Video(id='4yNswvhPWCQ', title='Build an LLM from Scratch 7: Instruction Finetuning', url='https://www.youtube.com/watch?v=4yNswvhPWCQ', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 4, 11, 17, 17, 37)), Video(id='5PFXJYme4ik', title='Build an LLM from Scratch 6: Finetuning for Classification', url='https://www.youtube.com/watch?v=5PFXJYme4ik', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 4, 4, 19, 19, 37)), Video(id='Zar2TJv-sE0', title='Build an LLM from Scratch 5: Pretraining on Unlabeled Data', url='https://www.youtube.com/watch?v=Zar2TJv-sE0', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 3, 23, 10, 33)), Video(id='YSAkgEarBGE', title='Build an LLM from Scratch 4: Implementing a GPT model from Scratch To Generate Text', url='https://www.youtube.com/watch?v=YSAkgEarBGE', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 3, 17, 15, 24, 30)), Video(id='-Ll8DtpNtvk', title='Build an LLM from Scratch 3: Coding attention mechanisms', url='https://www.youtube.com/watch?v=-Ll8DtpNtvk', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 3, 11, 15, 42, 6)), Video(id='341Rb8fJxY0', title='Build an LLM from Scratch 2: Working with text data', url='https://www.youtube.com/watch?v=341Rb8fJxY0', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 3, 2, 14, 15)), Video(id='yAcWnfsZhzo', title='Build an LLM from Scratch 1: Set up your code environment', url='https://www.youtube.com/watch?v=yAcWnfsZhzo', description='Links to the book: - https://amzn.to/4fqvn0D (Amazon) - https://mng.bz/M96o (Manning) Link to the GitHub repository: ...', published_at=datetime.datetime(2025, 2, 26, 18, 10, 11)), Video(id='vJ4SsfmeQlk', title='Reinforcement Learning with Human Feedback (RLHF) in 4 minutes', url='https://www.youtube.com/watch?v=vJ4SsfmeQlk', description='Understanding Reinforcement Learning with Human Feedback (RLHF) – A short clip from my talk at the 2023 Optimized AI ...', published_at=datetime.datetime(2025, 2, 8, 17, 49, 45)), Video(id='itIab9ZTAqk', title='LLMs: A Journey Through Time and Architecture', url='https://www.youtube.com/watch?v=itIab9ZTAqk', description='REFERENCES: - Step-by-step guide converting GPT to Llama: ...', published_at=datetime.datetime(2024, 9, 24, 12, 3)), Video(id='quh7z1q7-uc', title='Building LLMs from the Ground Up: A 3-hour Coding Workshop', url='https://www.youtube.com/watch?v=quh7z1q7-uc', description='REFERENCES: 1. Build an LLM from Scratch book: https://amzn.to/4fqvn0D 2. Build an LLM from Scratch repo: ...', published_at=datetime.datetime(2024, 8, 31, 10, 36, 48)), Video(id='PetlIokI9Ao', title='Understanding PyTorch Buffers', url='https://www.youtube.com/watch?v=PetlIokI9Ao', description="Sebastian's books: https://sebastianraschka.com/books/ This video explains what PyTorch buffers are, a concept that is ...", published_at=datetime.datetime(2024, 7, 27, 21, 45, 55)), Video(id='kPGTx4wcm_w', title='Developing an LLM: Building, Training, Finetuning', url='https://www.youtube.com/watch?v=kPGTx4wcm_w', description='REFERENCES: 1. Build an LLM from Scratch book: https://amzn.to/4fqvn0D 2. Build an LLM from Scratch repo: ...', published_at=datetime.datetime(2024, 6, 6, 12, 0, 48)), Video(id='ii89_SqKB0 ...
#  Channel(id='UC8butISFwT-Wl7EV0hUK0BQ', name='FreeCodeCamp.org', videos=[Video(id='FHLmuNj20bA', title='Ditching My Microsoft Job for Startup Purgatory with Sam Crombie [Podcast #171]', url='https://www.youtube.com/watch?v=FHLmuNj20bA', description="On this week's episode of the podcast, freeCodeCamp founder Quincy Larson interviews Sam Crombie. He's a software engineer ...", published_at=datetime.datetime(2025, 5, 9, 9, 0, 32)), Video(id='DOXJ7s1D6iE', title='Generative AI Bootcamp – Complete 65-Hour Course', url='https://www.youtube.com/watch?v=DOXJ7s1D6iE', description='This free GenAI Bootcamp is designed to equip you with foundational and practical knowledge for working with AI in the cloud.', published_at=datetime.datetime(2025, 5, 8, 14, 52, 44)), Video(id='IcOiX-jynfI', title='Learn Next.js by Coding Your Own Dropbox Clone – Full Tutorial', url='https://www.youtube.com/watch?v=IcOiX-jynfI', description="Welcome to this hands-on course where you'll learn to build Droply, a Dropbox-inspired file storage service, using the latest tools ...", published_at=datetime.datetime(2025, 5, 7, 15, 12, 21)), Video(id='G4A5T3y5bJM', title='C++ Course: Build an Audio Plugin', url='https://www.youtube.com/watch?v=G4A5T3y5bJM', description="Improve you C++ skills in this course on creating a music plugin with C++ and the JUCE framework. You'll learn how to set up ...", published_at=datetime.datetime(2025, 5, 5, 15, 53, 27)), Video(id='biveB0gOlak', title='Code Your Own Llama 4 LLM from Scratch – Full Course', url='https://www.youtube.com/watch?v=biveB0gOlak', description='This course is a guide to understanding and implementing Llama 4. @vukrosic will teach you how to code Llama 4 from scratch.', published_at=datetime.datetime(2025, 4, 24, 15, 33, 8)), Video(id='0ffwhxW-uyw', title='C++ Setup and Installation Tools – CMake, vcpkg, Docker &amp; Copilot', url='https://www.youtube.com/watch?v=0ffwhxW-uyw', description='Master the essential tools for modern C++ development with this comprehensive course that covers environment setup across ...', published_at=datetime.datetime(2025, 4, 8, 14, 55, 10)), Video(id='876aSEUA_8c', title='JavaScript Essentials Course – Foundational JS Skills for New Developers Tutorial', url='https://www.youtube.com/watch?v=876aSEUA_8c', description='Learn JavaScript essentials with this course that covers everything from object-oriented programming fundamentals to advanced ...', published_at=datetime.datetime(2025, 3, 12, 18, 6, 3)), Video(id='_CXwZ5xyFno', title='DeepSeek-R1 Crash Course', url='https://www.youtube.com/watch?v=_CXwZ5xyFno', description='Learn how to use DeepSeek-R1 in this crash course for beginners. Learn about the innovative reinforcement learning approach ...', published_at=datetime.datetime(2025, 1, 28, 15, 52, 11)), Video(id='eX-ODcr3XJg', title='Polyrhythms JavaScript Project Tutorial – How Math Can Make Your Code Better', url='https://www.youtube.com/watch?v=eX-ODcr3XJg', description='In this JavaScript course, @Radu will teach you about good coding practices when building a fun project. It emphasizes how ...', published_at=datetime.datetime(2024, 12, 10, 16, 58, 24)), Video(id='GWB9ApTPTv4', title='Ollama Course – Build AI Apps Locally', url='https://www.youtube.com/watch?v=GWB9ApTPTv4', description='Learn how to set up and use Ollama to build powerful AI applications locally. This hands-on course covers pulling and ...', published_at=datetime.datetime(2024, 11, 26, 15, 29, 4)), Video(id='F0GQ0l2NfHA', title='Generative AI for Developers – Comprehensive Course', url='https://www.youtube.com/watch?v=F0GQ0l2NfHA', description="In this comprehensive Generative AI course from @dswithbappy, you'll dive deep into the world of generative AI, exploring key ...", published_at=datetime.datetime(2024, 10, 31, 13, 56, 9)), Video(id='pPqazMTzNOM', title='Databases In-Depth – Complete Course', url='https://www.youtube.com/watch?v=pPqazMTzNOM', description='Learn all about databases in this course desig ...
